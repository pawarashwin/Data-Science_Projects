# %% [markdown]
# # **Transforming EDA Projects to Dashboards**
#
# **Create Stunning Tableau Dashboard from the same dataset on which EDA was performed for the capstone project.**
#
# Suppose, **if someone performed EDA on Airbnb operations** then the following steps need to be followed for building an adequate dashboard through which one can analyse the performance of the company to take necessary actions.
#
# **Problem Statement:**
#
# In the context of Airbnb operations, how can the utilisation of Tableau facilitate a comprehensive comparative examination between Chicago and New Orleans, two diverse urban environments?
#
# This inquiry seeks to leverage Tableau's visual analytics capabilities to uncover and illustrate the shared attributes, disparities, and distinctive patterns inherent to Airbnb's presence in these cities, thus elevating the depth and insightfulness of the study.

# %% [markdown]
# **Dataset Selection:**
#
# For this EDA project, we have chosen the "Airbnb Listings Data" dataset from 2 major cities: Chicago and New Orleans. This dataset provides a comprehensive snapshot of various attributes related to Airbnb listings, such as property type, neighbourhood, pricing, availability, and more. The dataset is ideal for conducting an in-depth exploration of the local Airbnb market and deriving actionable insights.
#
# **Why Airbnb:**
#
# Airbnb, a prominent online platform, enables individuals to reserve accommodations spanning a spectrum from beds and rooms to apartments and entire homes across global locales. This user-centric platform serves as a conduit for seamless property rentals, negating the need for intricate intermediaries or substantial capital outlays. Notably, users can secure lodgings at significantly competitive rates relative to traditional hotels. Distinctively, Airbnb extends its reach to regions where convectional hotel presence might be limited, offering an avenue for lodging acquisition in underserved locales. Moreover, the inclination towards immersive local experiences often steers individuals towards selecting accommodations embedded within native communities, fostering a distinctive preference for authenticity and cultural engagement.
#
# Airbnb Statistics • Over 4 million listings worldwide • 150 million users in 191 countries • Worldwide value is $32 billion • Global growth rate since 2009 - 153%

# %% [markdown]
# ##### **Project Type**    - EDA_Airbnb_Tableau_project
# ##### **Contribution**    - Individual
# ##### **Name -**Ashwin Pawar

# %% [markdown]
# **GitHub** - https://github.com/pawarashwin/Data-Science_Projects/tree/main/Tableau_Project

# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Dataset loading
#chicago
database = "/content/drive/MyDrive/cap_project/tableau project/chicago (1).csv"
chica_df =pd.read_csv(database)
# new or
database = "/content/drive/MyDrive/cap_project/tableau project/new orl 2.csv"
new_or_df =pd.read_csv(database)

# %%
# Dataset loading
#chicago
#chica_df = pd.read_csv('/content/chicago (1).csv', low_memory=False)
# new or
#new_or_df = pd.read_csv('/content/new orl 2.csv', low_memory=False)

# %%
#dataset first look chicago
chica_df.head()
# Out:
#           id                                               name  host_id  \
# 0     2384.0  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...     2613
# 1     7126.0  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...    17928
# 2    10945.0  Rental unit in Chicago · ★4.63 · 2 bedrooms · ...    33004
# 3  1461451.0  Rental unit in Chicago · ★4.60 · 1 bedroom · 1...  2907254
# 4  1502674.0  Rental unit in Chicago · ★4.79 · 2 bedrooms · ...    33004
#
#      host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0      Rebecca                  NaN     Hyde Park  41.78790  -87.58780
# 1        Sarah                  NaN     West Town  41.90166  -87.68021
# 2  At Home Inn                  NaN  Lincoln Park  41.91196  -87.63981
# 3          Joe                  NaN    West Ridge  42.01653  -87.68788
# 4  At Home Inn                  NaN  Lincoln Park  41.91175  -87.63834
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#dataset first look new orland
new_or_df.head()
# Out:
#         id                                               name  host_id  \
# 0  19091.0  Rental unit in New Orleans · ★4.89 · 1 bedroom...    72880
# 1  71624.0  Rental unit in New Orleans · ★4.94 · 1 bedroom...   367223
# 2  74498.0  Rental unit in New Orleans · ★4.90 · 1 bedroom...   391462
# 3  79536.0  Rental unit in New Orleans · ★4.89 · 1 bedroom...   428362
# 4  79609.0  Guest suite in New Orleans · ★4.96 · 2 bedroom...   428909
#
#   host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0      John                  NaN      Leonidas  29.96100  -90.11950
# 1     Susan                  NaN       Bywater  29.96153  -90.04364
# 2   Georgia                  NaN      St. Roch  29.96986  -90.05172
# 3    Miriam                  NaN  Seventh Ward  29.97803  -90.07450
# 4   Stephen                  NaN    St. Claude  29.96448  -90.03667
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# rows and columns count of chicago
chica_df.shape
# Out:
# (8949, 18)

# %%
# rows and columns count of new orland
new_or_df.shape
# Out:
# (7075, 18)

# %%
# column name in chicago
chica_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
# column  name in new orland
new_or_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
# data information
new_or_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7075 entries, 0 to 7074
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7075 non-null   float64
#  1   name                            7075 non-null   object
#  2   host_id                         7075 non-null   int64
#  3   host_name                       7075 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   7075 non-null   object
#  6   latitude                        7075 non-null   float64
#  7   longitude                       7075 non-null   float64
#  8   room_type                       7075 non-null   object
#  9   price                           7075 non-null   int64
#  10  minimum_nights                  7075 non-null   int64
#  11  number_of_reviews               7075 non-null   int64
# ...

# %%
chica_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8949 entries, 0 to 8948
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              8949 non-null   float64
#  1   name                            8949 non-null   object
#  2   host_id                         8949 non-null   int64
#  3   host_name                       8949 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   8949 non-null   object
#  6   latitude                        8949 non-null   float64
#  7   longitude                       8949 non-null   float64
#  8   room_type                       8949 non-null   object
#  9   price                           8338 non-null   float64
#  10  minimum_nights                  8949 non-null   int64
#  11  number_of_reviews               8949 non-null   int64
# ...

# %%
chica_df.describe().transpose()
# Out:
#                                  count          mean           std  \
# id                              8949.0  4.189903e+17  4.246817e+17
# host_id                         8949.0  1.829973e+08  1.708264e+08
# neighbourhood_group                0.0           NaN           NaN
# latitude                        8949.0  4.189233e+01  6.226451e-02
# longitude                       8949.0 -8.766197e+01  4.395103e-02
# price                           8338.0  1.731678e+02  1.112350e+03
# minimum_nights                  8949.0  1.588144e+01  4.114484e+01
# number_of_reviews               8949.0  4.677316e+01  8.997754e+01
# reviews_per_month               7042.0  1.834915e+00  1.858998e+00
# calculated_host_listings_count  8949.0  5.598536e+01  1.640768e+02
# availability_365                8949.0  1.899323e+02  1.400885e+02
# number_of_reviews_ltm           8949.0  1.293362e+01  2.011990e+01
#
#                                         min           25%           50%  \
# ...

# %%
new_or_df.describe().transpose()
# Out:
#                                  count          mean           std  \
# id                              7075.0  3.311980e+17  4.035353e+17
# host_id                         7075.0  1.894689e+08  1.728363e+08
# neighbourhood_group                0.0           NaN           NaN
# latitude                        7075.0  2.995859e+01  2.408300e-02
# longitude                       7075.0 -9.007402e+01  3.088158e-02
# price                           7075.0  2.065939e+02  2.817141e+02
# minimum_nights                  7075.0  1.237696e+01  1.989184e+01
# number_of_reviews               7075.0  6.301880e+01  9.467579e+01
# reviews_per_month               5944.0  1.752934e+00  1.693590e+00
# calculated_host_listings_count  7075.0  1.314898e+01  2.318787e+01
# availability_365                7075.0  1.627131e+02  1.306776e+02
# number_of_reviews_ltm           7075.0  1.359505e+01  2.120379e+01
#
#                                         min           25%           50%  \
# ...

# %%
# null values in chicago
chica_df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               8949
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                              611
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1907
# reviews_per_month                 1907
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1671
# dtype: int64

# %%
# null values in new orland
new_or_df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            0
# neighbourhood_group               7075
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       1131
# reviews_per_month                 1131
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           1299
# dtype: int64

# %%
import missingno as msno

# Visualize missing values of chicago using a heatmap
msno.heatmap(chica_df)
# Out:
# <Axes: >

# %%
# Visualize missing values of new orland using a heatmap
msno.heatmap(new_or_df)
# Out:
# <Axes: >

# %%
# finding unique values in chicago
chica_df.nunique()
# Out:
# id                                8668
# name                              3740
# host_id                           3992
# host_name                         2184
# neighbourhood_group                  0
# neighbourhood                       77
# latitude                          7309
# longitude                         7056
# room_type                            4
# price                              627
# minimum_nights                      56
# number_of_reviews                  428
# last_review                        948
# reviews_per_month                  667
# calculated_host_listings_count      44
# availability_365                   366
# number_of_reviews_ltm              121
# license                           4429
# dtype: int64

# %%
# finding unique values in new orland
new_or_df.nunique()
# Out:
# id                                6821
# name                              3698
# host_id                           3464
# host_name                         1810
# neighbourhood_group                  0
# neighbourhood                       68
# latitude                          5232
# longitude                         5416
# room_type                            4
# price                              691
# minimum_nights                      33
# number_of_reviews                  438
# last_review                        844
# reviews_per_month                  634
# calculated_host_listings_count      43
# availability_365                   366
# number_of_reviews_ltm              116
# license                           4052
# dtype: int64

# %%
concatenated_df = pd.concat([chica_df, new_or_df], axis=0, ignore_index=True)

# %%
concatenated_df.shape
# Out:
# (16024, 18)

# %%
concatenated_df.head()
# Out:
#           id                                               name  host_id  \
# 0     2384.0  Condo in Chicago · ★4.99 · 1 bedroom · 1 bed ·...     2613
# 1     7126.0  Rental unit in Chicago · ★4.70 · 1 bedroom · 1...    17928
# 2    10945.0  Rental unit in Chicago · ★4.63 · 2 bedrooms · ...    33004
# 3  1461451.0  Rental unit in Chicago · ★4.60 · 1 bedroom · 1...  2907254
# 4  1502674.0  Rental unit in Chicago · ★4.79 · 2 bedrooms · ...    33004
#
#      host_name  neighbourhood_group neighbourhood  latitude  longitude  \
# 0      Rebecca                  NaN     Hyde Park  41.78790  -87.58780
# 1        Sarah                  NaN     West Town  41.90166  -87.68021
# 2  At Home Inn                  NaN  Lincoln Park  41.91196  -87.63981
# 3          Joe                  NaN    West Ridge  42.01653  -87.68788
# 4  At Home Inn                  NaN  Lincoln Park  41.91175  -87.63834
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
concatenated_df.describe().transpose()
# Out:
#                                   count          mean           std  \
# id                              16024.0  3.802278e+17  4.177460e+17
# host_id                         16024.0  1.858546e+08  1.717414e+08
# neighbourhood_group                 0.0           NaN           NaN
# latitude                        16024.0  3.662328e+01  5.926318e+00
# longitude                       16024.0 -8.872695e+01  1.198410e+00
# price                           15413.0  1.885113e+02  8.402522e+02
# minimum_nights                  16024.0  1.433412e+01  3.351289e+01
# number_of_reviews               16024.0  5.394602e+01  9.243132e+01
# reviews_per_month               12986.0  1.797390e+00  1.785589e+00
# calculated_host_listings_count  16024.0  3.707202e+01  1.253952e+02
# availability_365                16024.0  1.779143e+02  1.366795e+02
# number_of_reviews_ltm           16024.0  1.322566e+01  2.060746e+01
#
#                                        min           25%           50%  \
# ...

# %%
concatenated_df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               16024
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                               611
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        3038
# reviews_per_month                  3038
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                            2970
# dtype: int64

# %%
concatenated_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
#  dataset fill into null values
concatenated_df['neighbourhood_group'] = concatenated_df['neighbourhood_group'].fillna(0)
concatenated_df['price'] = concatenated_df['price'].fillna(0)
concatenated_df['last_review'] = concatenated_df['last_review'].fillna(0)
concatenated_df['reviews_per_month'] = concatenated_df['reviews_per_month'].fillna(0)
concatenated_df['license'] = concatenated_df['license'].fillna(0)

# %%
concatenated_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# license                           0
# dtype: int64

# %%
concatenated_df.describe().transpose()
# Out:
#                                   count          mean           std  \
# id                              16024.0  3.802278e+17  4.177460e+17
# host_id                         16024.0  1.858546e+08  1.717414e+08
# neighbourhood_group             16024.0  0.000000e+00  0.000000e+00
# latitude                        16024.0  3.662328e+01  5.926318e+00
# longitude                       16024.0 -8.872695e+01  1.198410e+00
# price                           16024.0  1.813233e+02  8.248664e+02
# minimum_nights                  16024.0  1.433412e+01  3.351289e+01
# number_of_reviews               16024.0  5.394602e+01  9.243132e+01
# reviews_per_month               16024.0  1.456622e+00  1.755054e+00
# calculated_host_listings_count  16024.0  3.707202e+01  1.253952e+02
# availability_365                16024.0  1.779143e+02  1.366795e+02
# number_of_reviews_ltm           16024.0  1.322566e+01  2.060746e+01
#
#                                        min           25%           50%  \
# ...

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16024 entries, 0 to 16023
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16024 non-null  float64
#  1   name                            16024 non-null  object
#  2   host_id                         16024 non-null  int64
#  3   host_name                       16024 non-null  object
#  4   neighbourhood_group             16024 non-null  float64
#  5   neighbourhood                   16024 non-null  object
#  6   latitude                        16024 non-null  float64
#  7   longitude                       16024 non-null  float64
#  8   room_type                       16024 non-null  object
#  9   price                           16024 non-null  float64
#  10  minimum_nights                  16024 non-null  int64
#  11  number_of_reviews               16024 non-null  int64
# ...

# %%
concatenated_df.to_csv('concatenated_file.csv', index=False)

# Download the CSV file to your local machine
from google.colab import files
files.download('concatenated_file.csv')

# %%
concatenated_df["last_review"].unique()
# Out:
# array(['31-10-2023', '09-10-2023', '06-11-2023', ..., '18-12-2022',
#        '01-02-2023', '16-01-2023'], dtype=object)

# %%
print(concatenated_df['last_review'].head())
# Out:
# 0    31-10-2023
# 1    09-10-2023
# 2    06-11-2023
# 3    21-11-2023
# 4    10-12-2023
# Name: last_review, dtype: object

# %%
invalid_dates = concatenated_df[~pd.to_datetime(concatenated_df['last_review'], errors='coerce').notnull()]['last_review']
print(invalid_dates.value_counts())
# Out:
# last_review
# 0    3038
# Name: count, dtype: int64
# <ipython-input-80-f02113647219>:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   invalid_dates = concatenated_df[~pd.to_datetime(concatenated_df['last_review'], errors='coerce').notnull()]['last_review']

# %%
# Replace invalid dates with a valid date, such as the earliest or latest date in the column.
concatenated_df['last_review'] = pd.to_datetime(concatenated_df['last_review'], errors='coerce')
concatenated_df['last_review'].fillna(concatenated_df['last_review'].min(), inplace=True)

# Alternatively, drop rows with invalid dates.
concatenated_df = concatenated_df[pd.to_datetime(concatenated_df['last_review'], errors='coerce').notnull()]
# Out:
# <ipython-input-81-71c326c6b320>:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   concatenated_df['last_review'] = pd.to_datetime(concatenated_df['last_review'], errors='coerce')

# %%
concatenated_df['last_review'] = pd.to_datetime(concatenated_df['last_review']).dt.date

# %%
concatenated_df['last_review'] = pd.to_datetime(concatenated_df['last_review']).dt.date

# %%
concatenated_df["last_review"].unique()
# Out:
# array([datetime.date(2023, 10, 31), datetime.date(2023, 10, 9),
#        datetime.date(2023, 11, 6), ..., datetime.date(2022, 12, 18),
#        datetime.date(2023, 2, 1), datetime.date(2023, 1, 16)],
#       dtype=object)

# %%
concatenated_df['name'].str.split('.')
# Out:
# 0        [Condo in Chicago · ★4, 99 · 1 bedroom · 1 bed...
# 1        [Rental unit in Chicago · ★4, 70 · 1 bedroom ·...
# 2        [Rental unit in Chicago · ★4, 63 · 2 bedrooms ...
# 3        [Rental unit in Chicago · ★4, 60 · 1 bedroom ·...
# 4        [Rental unit in Chicago · ★4, 79 · 2 bedrooms ...
#                                ...
# 16019    [Home in New Orleans · ★New · 6 bedrooms · 7 b...
# 16020    [Home in New Orleans · ★New · 3 bedrooms · 4 b...
# 16021    [Home in New Orleans · ★New · 2 bedrooms · 2 b...
# 16022    [Home in New Orleans · ★New · 1 bedroom · 1 be...
# 16023    [Home in New Orleans · ★New · 2 bedrooms · 3 b...
# Name: name, Length: 16024, dtype: object

# %%
# Split the 'name' column into multiple columns
split_data = concatenated_df['name'].str.split('·', expand=True)

# Print the split data to debug
print(split_data)

# Assign the split columns to the DataFrame
# Verify that the number of columns matches the number of columns you're assigning to
concatenated_df[['ProN', 'Rate', 'room', 'Bed', 'Bath']] = split_data
# Out:
#                              0        1             2         3  \
# 0            Condo in Chicago    ★4.99     1 bedroom     1 bed
# 1      Rental unit in Chicago    ★4.70     1 bedroom     1 bed
# 2      Rental unit in Chicago    ★4.63    2 bedrooms    2 beds
# 3      Rental unit in Chicago    ★4.60     1 bedroom     1 bed
# 4      Rental unit in Chicago    ★4.79    2 bedrooms    2 beds
# ...                        ...      ...           ...       ...
# 16019     Home in New Orleans     ★New    6 bedrooms    7 beds
# 16020     Home in New Orleans     ★New    3 bedrooms    4 beds
# 16021     Home in New Orleans     ★New    2 bedrooms    2 beds
# 16022     Home in New Orleans     ★New     1 bedroom     1 bed
# 16023     Home in New Orleans     ★New    2 bedrooms    3 beds
#
#                      4
# 0        1 shared bath
# 1               1 bath
# 2               1 bath
# 3       2 shared baths
# 4               1 bath
# ...                ...
# 16019        3.5 baths
# ...

# %%
split_data.describe()
# Out:
#                               0            1            2        3        4
# count                     16024        16024        16024    15996    12259
# unique                       94          152           44       59       39
# top     Rental unit in Chicago    1 bedroom    1 bedroom    1 bed    1 bath
# freq                       5346         1850         4790     4000     5935

# %%
split_data.head()
# Out:
#                          0        1             2         3                4
# 0        Condo in Chicago    ★4.99     1 bedroom     1 bed     1 shared bath
# 1  Rental unit in Chicago    ★4.70     1 bedroom     1 bed            1 bath
# 2  Rental unit in Chicago    ★4.63    2 bedrooms    2 beds            1 bath
# 3  Rental unit in Chicago    ★4.60     1 bedroom     1 bed    2 shared baths
# 4  Rental unit in Chicago    ★4.79    2 bedrooms    2 beds            1 bath
